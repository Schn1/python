# %% [markdown]
# # Chap6
# os套件:用來處理文件與目錄,與檔案相關操作

# %%
import os 
print(os.getcwd())#顯示目前所在的工作目錄
# Out:
# /content

# %% [markdown]
# #顯示目錄下的檔案

# %%
os.listdir(".")
# Out:
# ['.config', 'a.text', 'a.txt', 'sample_data']

# %% [markdown]
# ## 檔案處理
# os套件有自己的檔案處理命令, 而比較常用的是python內建的open
# * w =可寫(預設建立檔案)若檔案存在則會清除舊檔案
# * w+ =可寫可讀(預設建立檔案)若檔案存在則會清除舊檔案
# * r =可讀
# * r+ =可寫可讀但寫入資料指向開頭
# * a =可寫不能讀 寫入資料指向尾端
# * a+ = 可寫可讀 寫入資料指向尾端
# * b =轉為二進位文件
# * ab+ =2進位文件的讀寫 寫入資料指向尾端

# %%
#新增目錄
os.makedirs("text")
os.listdir(".")
# Out:
# ['.config', 'text', 'sample_data']

# %%
#移除目錄
os.rmdir("text")
os.listdir(".")
# Out:
# ['.config', 'sample_data']

# %%
a=open("a.text","w")#新增檔案
a.write("This is a test1")
a.write("This is a test2\n")
a.write("This is a test3\n")
a.close()#關閉檔案

# %% [markdown]
# ## 檢查檔案是否存在

# %%
os.path.isfile("a.text")
# Out:
# True

# %% [markdown]
# ## 讀取檔案

# %%
a=open("a.text","r")
print(a.readline())
print(a.readline())
print(a.readline()) #多餘的命令, 檔案只有2行
a.close()
# Out:
# This is a test1This is a test2
#
# This is a test3

# %%
a=open("a.text","r")
print(a.readlines()) #一次讀取多行與a.read()命令相同
a.close()
# Out:
# ['This is a test1This is a test2\n', 'This is a test3\n']

# %%
#加上檔案是否存在的判斷
if os.path.isfile("a.txt"):
  a=open("a.txt","r")
  print(a.readlines())
  a.clsoe()
else:
    print("檔案不存在")
# Out:
# ['This is test4\n']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-1354c1e485e6> in <module>()
#       3   a=open("a.txt","r")
#       4   print(a.readlines())
# ----> 5   a.clsoe()
#       6 else:
#       7     print("檔案不存在")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'clsoe'

# %% [markdown]
# Split函式

# %%
if os.path.isfile("a.text"):
  a=open("a.text","r")
  for line in a:
    fields=line.split("   ")#以空白為切割欄位
    print(fields)
else:
  print("檔案不存在")

# %% [markdown]
# 附加檔案

# %%
a=open("a.txt","a")
a.write("This is test4\n")
a.close()

# %%
a=open("a.txt","r")
print(a.readlines())
a.close()

# %% [markdown]
# 比較a與r+的不同
# * a寫在檔案的結尾
# * r+寫在檔案的開頭

# %%
a=open("a.text","r+" )
a.write("This is test5\n")
a.close()

# %%
a=open("a.txt","r")
print(a.readlines())
a.close()
# Out:
# ['This is test4\n']

# %% [markdown]
# 刪除檔案

# %%
if os.path.isfile("a.txt"):
  os.remove("a.txt")
  print("檔案刪除成功")
else:
  print("找不到檔案")
  print(os.path.isfile("a.txt"))
# Out:
# 檔案刪除成功
